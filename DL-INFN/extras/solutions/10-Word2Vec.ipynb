# %% [markdown]
# # Word2Vec
#
#
# Word2vec is a widely-used algorithm for learning embeddings of words. It is an interesting algorithm and is surprising in its effectiveness.
#
# Adapted from https://github.com/tensorflow/tensorflow/blob/r0.7/tensorflow/examples/tutorials/word2vec/word2vec_basic.py

# %%
# %matplotlib inline

from sklearn.manifold import TSNE
import matplotlib.pyplot as plt
from collections import deque, Counter
import os
import zipfile
import numpy as np
import urllib2
import random
import tensorflow as tf
import math
from sklearn.cross_validation import train_test_split

# %% [markdown]
# First download the data we will use, e.g.
#
# ```
# curl -O http://mattmahoney.net/dc/text8.zip
# ```
#
# This dataset is a small exerpt of wikipedia with all punctuation removed.

# %%
# Read the data into a string.
def read_data(filename):
    f = zipfile.ZipFile(filename)
    for name in f.namelist():
        return f.read(name).split()
    f.close()

words = read_data('text8.zip')
print 'Data size', len(words)
# Out:
# Data size 17005207

# %% [markdown]
# We prepare the dataset by replacing rare words with a single "UNK" word (for "unknown"). This allows us to control the vocabulary size that we want to learn embeddings for. We assign each word in the vocabulary an index and we create a mapping between words and their indexes.

# %%
def build_dataset(words, vocabulary_size):
    count = [['UNK', -1]]
    count.extend(Counter(words).most_common(vocabulary_size - 1))
    dictionary = dict()
    for word, _ in count:
        dictionary[word] = len(dictionary)
    data = list()
    unk_count = 0
    for word in words:
        if word in dictionary:
            index = dictionary[word]
        else:
            index = 0  # dictionary['UNK']
            unk_count += 1
        data.append(index)
    count[0][1] = unk_count
    reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys()))
    return data, count, dictionary, reverse_dictionary

vocabulary_size = 50000

data, count, dictionary, reverse_dictionary = build_dataset(words, vocabulary_size)
del words  # Hint to reduce memory.
print 'Most common words (+UNK)', count[:5]
print 'Sample data', data[:10]
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5239, 3084, 12, 6, 195, 2, 3137, 46, 59, 156]

# %% [markdown]
# Next we define a function to generate batch from the data based on the parameters we set.
#
# For example, suppose we have this text data:
# ```
# the quick brown fox jumps over the lazy dog
# ```
#
# With a context window of 2 on either side of the target word, we have a total window size of 5:
# ```
# [the quick brown fox jumps] over the lazy dog
# ```
#
# From this window, we will generate training pairs:
# ```
# brown, the
# brown, quick
# brown, fox
# brown, jumps
# ```
#
# Then we will move on to the next window and do the same. The method below does this until we have enough pairs to fill up the batch size.

# %%
data_index = 0
def generate_batch(batch_size, num_skips, skip_window):
    """
    batch_size - the number of pairs in the batch
    num_skips - number of targets to sample from a window
    skip_window - number of context words (on each side of target) in a window
    """
    global data_index
    assert batch_size % num_skips == 0
    assert num_skips <= 2 * skip_window

    batch = np.ndarray(shape=(batch_size), dtype=np.int32)
    labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
    span = 2 * skip_window + 1 # [ skip_window target skip_window ]
    buffer = deque(maxlen=span)

    # Add initial window of data to the deque
    for _ in range(span):
        buffer.append(data[data_index])
        data_index = (data_index + 1) % len(data)
        
    # Build a window's worth of pairs in each loop
    for i in range(batch_size // num_skips):
        target = skip_window  # target label at the center of the buffer
        targets_to_avoid = [ skip_window ]
        
        # Sample pairs from the current window
        for j in range(num_skips):
            
            # Reject samples we've already chosen
            while target in targets_to_avoid:
                target = random.randint(0, span - 1)
            targets_to_avoid.append(target)

            # Add center word and it's sample context word
            batch[i * num_skips + j] = buffer[skip_window]
            labels[i * num_skips + j, 0] = buffer[target]

        buffer.append(data[data_index])
        data_index = (data_index + 1) % len(data)
    return batch, labels




data_index = 0
batch, labels = generate_batch(batch_size=8, num_skips=2, skip_window=1)

print(data[:10])

for i in range(8):
    print batch[i], '->', labels[i, 0], '(%s -> %s)' % (reverse_dictionary[batch[i]], reverse_dictionary[labels[i, 0]])
# Out:
# [5239, 3084, 12, 6, 195, 2, 3137, 46, 59, 156]
# 3084 -> 12 (originated -> as)
# 3084 -> 5239 (originated -> anarchism)
# 12 -> 6 (as -> a)
# 12 -> 3084 (as -> originated)
# 6 -> 195 (a -> term)
# 6 -> 12 (a -> as)
# 195 -> 6 (term -> a)
# 195 -> 2 (term -> of)

# %% [markdown]
# Now we are ready to make the model.

# %%
batch_size = 128
embedding_size = 128  # Dimension of the embedding vector.
skip_window = 1       # How many words to consider left and right.
num_skips = 2         # How many times to reuse an input to generate a label.

# We pick a random validation set to sample nearest neighbors. Here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent.
valid_size = 16     # Random set of words to evaluate similarity on.
valid_window = 100  # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(np.arange(valid_window), valid_size))
num_sampled = 64    # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default():

    # Input data.
    train_inputs = tf.placeholder(tf.int32, shape=[batch_size])
    train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)

    # Ops and variables pinned to the CPU because of missing GPU implementation
    with tf.device('/cpu:0'):
        # Look up embeddings for inputs.
        embeddings = tf.Variable(
                tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
        embed = tf.nn.embedding_lookup(embeddings, train_inputs)

        # Construct the variables for the NCE loss
        nce_weights = tf.Variable(
                tf.truncated_normal([vocabulary_size, embedding_size],
                                                        stddev=1.0 / math.sqrt(embedding_size)))
        nce_biases = tf.Variable(tf.zeros([vocabulary_size]))

    # Compute the average NCE loss for the batch.
    # tf.nce_loss automatically draws a new sample of the negative labels each
    # time we evaluate the loss.
    loss = tf.reduce_mean(
            tf.nn.nce_loss(nce_weights, nce_biases, embed, train_labels,
                                         num_sampled, vocabulary_size))

    # Construct the SGD optimizer using a learning rate of 1.0.
    optimizer = tf.train.GradientDescentOptimizer(1.0).minimize(loss)

    # Compute the cosine similarity between minibatch examples and all embeddings.
    norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
    normalized_embeddings = embeddings / norm

    valid_embeddings = tf.nn.embedding_lookup(normalized_embeddings, valid_dataset)
    similarity = tf.matmul(valid_embeddings, normalized_embeddings, transpose_b=True)

    init = tf.initialize_all_variables()

# %% [markdown]
# Let's create a session and train the model.

# %%
num_steps = 100001

sess = tf.Session(graph=graph)

# We must initialize all variables before we use them.
sess.run(init)
print 'Initialized'

average_loss = 0
for step in xrange(num_steps):
    batch_inputs, batch_labels = generate_batch(batch_size, num_skips, skip_window)
    feed_dict = {train_inputs : batch_inputs, train_labels : batch_labels}

    # We perform one update step by evaluating the optimizer op (including it
    # in the list of returned values for session.run()
    _, loss_val = sess.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += loss_val

    if step % 2000 == 0:
        if step > 0:
            average_loss /= 2000
        # The average loss is an estimate of the loss over the last 2000 batches.
        print "Average loss at step ", step, ": ", average_loss
        average_loss = 0

    # Note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
        sim = sess.run(similarity)
        for i in xrange(valid_size):
            valid_word = reverse_dictionary[valid_examples[i]]
            top_k = 8 # number of nearest neighbors
            nearest = (-sim[i, :]).argsort()[1:top_k+1]
            log_str = "Nearest to %s:" % valid_word
            for k in xrange(top_k):
                close_word = reverse_dictionary[nearest[k]]
                log_str = "%s %s," % (log_str, close_word)
            print(log_str)

final_embeddings = sess.run(normalized_embeddings)
# Out:
# Initialized
# Average loss at step  0 :  248.010314941
# Nearest to while: searle, reconsider, soften, photographing, strip, peng, passer, pd,
# Nearest to UNK: ash, muppets, contradicts, rhus, cartel, publicity, speeches, jam,
# Nearest to five: standardisation, gets, wawel, pong, prejudices, normalised, feynman, voiced,
# Nearest to they: baffling, episcopalians, wftu, coalition, lard, focussed, electorate, dolmens,
# Nearest to a: kaohsiung, qt, oversaw, motivational, competes, headstock, squatters, facilitation,
# Nearest to s: anarchic, ecclesiastica, flagella, franchising, yttrium, politicians, catching, otto,
# Nearest to on: tejada, nobody, burlesque, contemptuous, stalking, rebus, naively, gto,
# Nearest to many: lookout, harmonisation, coronal, escalated, shouted, stoke, bundesland, taverns,
# Nearest to their: geyser, pancake, judicious, proceed, shakur, thirds, cline, ange,
# Nearest to four: friedrich, characterizes, sociologist, quae, ginsberg, rationality, cistern, gothenburg,
# Nearest to zero: grimes, unitarians, foundered, piccolo, impartiality, underbelly, aronson, bekenstein,
# Nearest to an: naacp, msc, inexplicably, acth, accrued, selection, zondervan, electronegative,
# Nearest to most: tasmania, paigc, bother, neat, april, muons, dari, regiments,
# Nearest to in: wake, inducted, jamaica, appropriation, ranches, roll, blot, potawatomi,
# Nearest to when: spirituals, farian, ifvs, peugeot, optimization, affray, catastrophic, amon,
# Nearest to if: samba, deux, socially, endosymbiosis, neural, catalytic, bijapur, curled,
# Average loss at step  2000 :  113.630811617
# Average loss at step  4000 :  53.0199192669
# Average loss at step  6000 :  33.0549619675
# Average loss at step  8000 :  23.5805776794
# Average loss at step  10000 :  17.7330429382
# Nearest to while: marple, strip, asterism, auteur, offense, qur, leonard, testament,
# Nearest to UNK: and, one, agave, austin, victoriae, reginae, analogue, two,
# Nearest to five: reginae, zero, vs, six, three, nine, march, one,
# Nearest to they: he, austin, market, amo, antarctic, victoriae, starred, reputation,
# Nearest to a: the, reginae, respectively, this, austin, UNK, one, analogue,
# Nearest to s: and, training, the, of, zero, agnostic, for, crowley,
# Nearest to on: in, for, of, marc, henry, legends, support, garbage,
# Nearest to many: reginae, myself, the, supplies, commons, solving, bowler, analogue,
# Nearest to their: reginae, proceed, hubbard, doctrine, his, cl, researchers, austin,
# Nearest to four: austin, three, nine, reginae, two, zero, five, mathbf,
# Nearest to zero: nine, six, gland, austin, analogue, vs, reginae, one,
# Nearest to an: the, convince, gb, settlement, reginae, translation, milestones, builder,
# Nearest to most: time, two, one, oxus, tasmania, april, interior, UNK,
# Nearest to in: of, and, for, with, by, on, from, nine,
# Nearest to when: ac, students, exists, suggests, micrometre, bauer, mughal, medical,
# Nearest to if: justice, austin, louise, biscuit, fundamentalism, socially, agave, neural,
# Average loss at step  12000 :  13.9188403224
# Average loss at step  14000 :  11.9053292848
# Average loss at step  16000 :  9.95462777245
# Average loss at step  18000 :  8.70386850619
# Average loss at step  20000 :  7.7442063446
# Nearest to while: marple, astoria, to, aquila, strip, asterism, archimedes, yard,
# Nearest to UNK: dasyprocta, agouti, reginae, agave, and, austin, two, apatosaurus,
# Nearest to five: zero, nine, eight, three, six, four, seven, two,
# Nearest to they: he, dasyprocta, there, austin, not, we, signatory, market,
# Nearest to a: the, dasyprocta, reginae, this, potato, his, agouti, one,
# Nearest to s: and, zero, the, training, of, five, his, basins,
# Nearest to on: in, for, and, of, agouti, two, with, mormonism,
# Nearest to many: reginae, lookout, myself, the, some, picirilli, cerro, supplies,
# Nearest to their: his, its, the, reginae, agouti, proceed, this, jupiter,
# Nearest to four: nine, five, three, seven, two, zero, eight, six,
# Nearest to zero: nine, five, seven, eight, six, four, three, two,
# Nearest to an: the, convince, dasyprocta, milestones, reginae, gb, builder, UNK,
# Nearest to most: time, tasmania, hbox, interior, regiments, oxus, birkenau, rocky,
# Nearest to in: and, of, for, on, at, with, from, by,
# Nearest to when: malignant, and, lyell, exists, hbox, agouti, ac, five,
# Nearest to if: louise, biscuit, justice, fundamentalism, socially, as, brittle, endomorphism,
# Average loss at step  22000 :  7.25631674743
# Average loss at step  24000 :  6.96054088211
# Average loss at step  26000 :  6.67942022502
# Average loss at step  28000 :  6.25270200288
# Average loss at step  30000 :  6.14423376417
# Nearest to while: astoria, and, marple, searle, to, aquila, abitibi, strip,
# Nearest to UNK: abitibi, abet, dasyprocta, agouti, agave, primigenius, reginae, aosta,
# Nearest to five: four, eight, six, three, seven, nine, zero, two,
# Nearest to they: he, there, we, not, dasyprocta, it, signatory, austin,
# Nearest to a: the, dasyprocta, this, reginae, abet, potato, any, agouti,
# Nearest to s: and, of, the, his, adrenal, zero, abet, five,
# Nearest to on: in, for, two, from, at, during, and, of,
# Nearest to many: some, several, reginae, lookout, the, myself, gatherings, cerro,
# Nearest to their: his, its, the, reginae, this, agouti, proceed, abet,
# Nearest to four: five, six, seven, eight, three, nine, two, zero,
# Nearest to zero: eight, five, six, four, nine, seven, three, two,
# Nearest to an: the, convince, acth, dasyprocta, chalukyas, builder, abakan, reginae,
# Nearest to most: wiles, hbox, regiments, interior, tasmania, time, rocky, birkenau,
# Nearest to in: and, at, of, from, for, with, on, by,
# Nearest to when: malignant, hbox, four, if, agouti, abitibi, was, five,
# Nearest to if: when, is, justice, louise, biscuit, fundamentalism, as, recapture,
# Average loss at step  32000 :  5.86527417171
# Average loss at step  34000 :  5.81644670284
# Average loss at step  36000 :  5.69050963783
# Average loss at step  38000 :  5.3077783035
# Average loss at step  40000 :  5.45575578856
# Nearest to while: astoria, and, to, marple, aquila, searle, abitibi, incompressible,
# Nearest to UNK: agouti, dasyprocta, abet, reginae, abitibi, trinomial, aosta, agave,
# Nearest to five: four, seven, three, eight, six, zero, two, nine,
# Nearest to they: he, there, we, it, not, dasyprocta, signatory, austin,
# Nearest to a: the, dasyprocta, reginae, abet, this, recitative, any, vojt,
# Nearest to s: his, adrenal, and, abet, zero, isbn, subkey, the,
# Nearest to on: in, at, from, for, during, with, opteron, agouti,
# Nearest to many: some, several, reginae, the, lookout, cerro, myself, such,
# Nearest to their: his, its, the, reginae, this, abet, her, agouti,
# Nearest to four: five, six, three, seven, eight, two, one, zero,
# Nearest to zero: five, seven, eight, six, nine, four, three, two,
# Nearest to an: the, convince, acth, abakan, dasyprocta, builder, chalukyas, imperial,
# Nearest to most: hbox, wiles, regiments, interior, birkenau, dari, more, basins,
# Nearest to in: at, and, from, with, of, on, ignosticism, for,
# Nearest to when: and, four, if, malignant, hbox, farian, five, before,
# Nearest to if: when, as, louise, but, is, justice, for, biscuit,
# Average loss at step  42000 :  5.31368575156
# Average loss at step  44000 :  5.32490997887
# Average loss at step  46000 :  5.29470521235
# Average loss at step  48000 :  5.0447103734
# Average loss at step  50000 :  5.16614790285
# Nearest to while: astoria, and, aquila, incompressible, abitibi, marple, if, searle,
# Nearest to UNK: dasyprocta, thibetanus, abitibi, agouti, abet, reginae, recitative, trinomial,
# Nearest to five: four, six, three, eight, seven, zero, two, nine,
# Nearest to they: he, there, we, it, not, dasyprocta, signatory, who,
# Nearest to a: the, reginae, dasyprocta, any, abet, alternatives, recitative, this,
# Nearest to s: adrenal, and, zero, his, five, abet, flutie, isbn,
# Nearest to on: in, at, from, during, for, among, and, agouti,
# Nearest to many: some, several, reginae, these, such, the, lookout, cerro,
# Nearest to their: its, his, the, her, reginae, primigenius, proceed, recitative,
# Nearest to four: three, five, six, eight, seven, two, one, zero,
# Nearest to zero: six, five, seven, eight, nine, four, three, two,
# Nearest to an: convince, the, acth, abakan, parochial, imperial, inexplicably, dasyprocta,
# Nearest to most: hbox, wiles, more, regiments, interior, birkenau, dari, sweep,
# Nearest to in: at, from, on, and, of, with, nine, reginae,
# Nearest to when: four, if, before, but, hbox, malignant, agouti, six,
# Nearest to if: when, but, as, louise, before, is, for, while,
# Average loss at step  52000 :  5.16624199259
# Average loss at step  54000 :  5.08959420323
# Average loss at step  56000 :  5.08004192376
# Average loss at step  58000 :  5.09368313038
# Average loss at step  60000 :  4.9458840757
# Nearest to while: and, astoria, microcebus, tamarin, abitibi, aquila, incompressible, dmt,
# Nearest to UNK: tamarin, thibetanus, callithrix, dasyprocta, abitibi, agouti, michelob, abet,
# Nearest to five: six, four, eight, three, seven, zero, nine, two,
# Nearest to they: he, there, we, it, not, dasyprocta, you, who,
# Nearest to a: the, callithrix, ssbn, wct, dasyprocta, reginae, this, any,
# Nearest to s: adrenal, his, zero, isbn, and, flutie, basins, five,
# Nearest to on: in, at, during, among, and, agouti, callithrix, for,
# Nearest to many: some, several, these, such, reginae, cebus, both, cerro,
# Nearest to their: its, his, the, her, reginae, these, some, proceed,
# Nearest to four: six, five, three, eight, seven, two, nine, zero,
# Nearest to zero: eight, six, five, seven, four, nine, three, callithrix,
# Nearest to an: convince, parochial, acth, balmoral, abakan, inexplicably, builder, the,
# Nearest to most: hbox, wiles, more, regiments, interior, callithrix, sweep, ssbn,
# Nearest to in: at, tamarin, wct, of, callithrix, on, and, from,
# Nearest to when: if, before, four, hbox, but, was, agouti, and,
# Nearest to if: when, but, for, is, before, louise, while, cebus,
# Average loss at step  62000 :  4.78031001842
# Average loss at step  64000 :  4.77467160106
# Average loss at step  66000 :  4.9801632961
# Average loss at step  68000 :  4.89870919859
# Average loss at step  70000 :  4.774496176
# Nearest to while: and, thaler, astoria, microcebus, tamarin, abitibi, in, if,
# Nearest to UNK: tamarin, callithrix, thaler, dasyprocta, thibetanus, dinar, abitibi, michelob,
# Nearest to five: four, six, three, eight, seven, zero, two, nine,
# Nearest to they: he, we, there, it, not, you, dasyprocta, who,
# Nearest to a: the, callithrix, ssbn, reginae, wct, dasyprocta, abet, beethoven,
# Nearest to s: adrenal, isbn, perihelion, thaler, flutie, dinar, his, mitral,
# Nearest to on: in, at, during, dinar, among, callithrix, under, lerner,
# Nearest to many: some, several, these, reginae, such, cebus, both, agouti,
# Nearest to their: its, his, the, her, some, reginae, these, proceed,
# Nearest to four: five, six, three, eight, seven, two, zero, nine,
# Nearest to zero: eight, five, six, seven, four, nine, three, callithrix,
# Nearest to an: convince, the, parochial, abakan, builder, acth, balmoral, inexplicably,
# Nearest to most: more, hbox, wiles, interior, regiments, callithrix, many, ssbn,
# Nearest to in: at, dinar, tamarin, on, callithrix, wct, for, during,
# Nearest to when: if, before, hbox, was, four, but, agouti, and,
# Nearest to if: when, before, while, for, but, louise, after, cebus,
# Average loss at step  72000 :  4.80555504107
# Average loss at step  74000 :  4.78401234478
# Average loss at step  76000 :  4.88919264299
# Average loss at step  78000 :  4.78187135017
# Average loss at step  80000 :  4.81532710683
# Nearest to while: thaler, and, astoria, microcebus, tamarin, vec, abitibi, if,
# Nearest to UNK: tamarin, callithrix, crb, dasyprocta, abitibi, thibetanus, cegep, dinar,
# Nearest to five: four, six, seven, eight, three, nine, zero, two,
# Nearest to they: he, we, there, it, you, not, who, dasyprocta,
# Nearest to a: the, ssbn, callithrix, any, dasyprocta, reginae, wct, pontificia,
# Nearest to s: flutie, isbn, zero, his, perihelion, thaler, mamertines, adrenal,
# Nearest to on: in, at, during, from, cegep, under, dinar, among,
# Nearest to many: some, several, these, such, reginae, cebus, both, cegep,
# Nearest to their: its, his, her, the, reginae, some, these, carabiners,
# Nearest to four: five, six, three, eight, seven, two, nine, zero,
# Nearest to zero: five, eight, seven, six, four, nine, three, tamarin,
# Nearest to an: parochial, convince, tailpiece, abakan, balmoral, the, acth, inexplicably,
# Nearest to most: more, cegep, many, hbox, interior, curl, wiles, regiments,
# Nearest to in: at, cegep, dinar, tamarin, wct, callithrix, during, on,
# Nearest to when: if, before, hbox, but, agouti, after, four, as,
# Nearest to if: when, before, while, for, but, after, louise, recapture,
# Average loss at step  82000 :  4.79910534024
# Average loss at step  84000 :  4.77947773921
# Average loss at step  86000 :  4.75914280796
# Average loss at step  88000 :  4.69243231726
# Average loss at step  90000 :  4.75342169046
# Nearest to while: and, thaler, microcebus, astoria, tamarin, verner, when, abitibi,
# Nearest to UNK: tamarin, dasyprocta, dinar, callithrix, thaler, thibetanus, abitibi, michelob,
# Nearest to five: four, seven, eight, six, three, nine, two, zero,
# Nearest to they: we, he, there, you, it, not, who, dasyprocta,
# Nearest to a: the, callithrix, ssbn, dasyprocta, reginae, wct, any, pontificia,
# Nearest to s: his, isbn, flutie, perihelion, adrenal, zero, thaler, pontificia,
# Nearest to on: at, in, dinar, during, cegep, upon, under, callithrix,
# Nearest to many: some, several, these, reginae, such, both, cebus, cegep,
# Nearest to their: its, his, her, the, some, reginae, these, carabiners,
# Nearest to four: five, seven, six, three, eight, two, nine, one,
# Nearest to zero: five, eight, seven, six, four, nine, three, mitral,
# Nearest to an: parochial, convince, the, abakan, acth, tailpiece, nie, balmoral,
# Nearest to most: more, cegep, many, hbox, some, curl, interior, ssbn,
# Nearest to in: at, tamarin, dinar, cegep, during, callithrix, and, ignosticism,
# Nearest to when: if, before, after, hbox, while, but, agouti, although,
# Nearest to if: when, for, before, while, after, but, louise, hbox,
# Average loss at step  92000 :  4.70105652988
# Average loss at step  94000 :  4.63344036847
# Average loss at step  96000 :  4.72941601241
# Average loss at step  98000 :  4.62187481451
# Average loss at step  100000 :  4.6791030345
# Nearest to while: and, when, thaler, microcebus, astoria, tamarin, but, abitibi,
# Nearest to UNK: tamarin, abitibi, callithrix, dasyprocta, agouti, thibetanus, dinar, michelob,
# Nearest to five: four, seven, six, eight, three, zero, nine, two,
# Nearest to they: we, he, there, you, it, not, who, these,
# Nearest to a: the, ssbn, any, callithrix, reginae, wct, dasyprocta, catolica,
# Nearest to s: his, isbn, thaler, flutie, pontificia, the, dinar, perihelion,
# Nearest to on: in, at, during, cegep, dinar, upon, under, against,
# Nearest to many: some, several, these, reginae, such, both, cebus, cegep,
# Nearest to their: its, his, the, her, some, these, carabiners, reginae,
# Nearest to four: five, seven, six, eight, three, two, nine, zero,
# Nearest to zero: five, eight, seven, six, four, nine, three, tamarin,
# Nearest to an: parochial, convince, tailpiece, acth, inexplicably, abakan, the, balmoral,
# Nearest to most: more, cegep, many, hbox, some, curl, interior, ssbn,
# Nearest to in: during, at, cegep, tamarin, dinar, within, from, on,
# Nearest to when: if, before, while, after, although, hbox, though, and,
# Nearest to if: when, for, before, while, after, so, but, louise,

# %% [markdown]
# ## Plot the embedding
#
# We can use tSNE to help understand what our model as learned. Inspect the embedding - what observations can you make?

# %%
def plot_with_labels(low_dim_embs, labels):
    assert low_dim_embs.shape[0] >= len(labels), "More labels than embeddings"
    plt.figure(figsize=(18, 18))  #in inches
    for i, label in enumerate(labels):
        x, y = low_dim_embs[i,:]
        plt.scatter(x, y)
        plt.annotate(label,
             xy=(x, y),
             xytext=(5, 2),
             textcoords='offset points',
             ha='right',
             va='bottom')
    plt.show()

def make_tsne(embeddings):
    tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
    plot_only = 500
    low_dim_embs = tsne.fit_transform(embeddings[:plot_only,:])
    labels = [reverse_dictionary[i] for i in xrange(plot_only)]
    plot_with_labels(low_dim_embs, labels)
    
make_tsne(final_embeddings)
